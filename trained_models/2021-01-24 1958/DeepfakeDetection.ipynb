# %%
import os
#os.environ['PYTHONHASHSEED'] = '0'

import tensorflow as tf
#tf.random.set_seed(89)

import numpy as np
#np.random.seed(42)

import random as rn
#rn.seed(1254)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Extract dataset

# %%
# %%capture
# !unzip -o "/content/drive/My Drive/Thesis/deepfake-detection-master/deepfake_database.zip" -d /content/

# %% [markdown]
# ## Parameters

# %%
BATCH_SIZE = 64
SIZE = 100
EPOCHS = 50

input_shape = (SIZE, SIZE, 3)
learning_rate = 0.001
dl_rate = 1

# %% [markdown]
# ## Store into tf.data.Dataset

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

directory = os.path.join('deepfake_database', 'train_test')
image_format = '.jpg'

training_dataset = image_dataset_from_directory(
    directory,
    labels="inferred",
    label_mode="binary",
    class_names=['df', 'real'],
    color_mode="rgb",
    batch_size=BATCH_SIZE,
    image_size=(SIZE, SIZE),
    shuffle=True,
    validation_split=0.1,
    subset="training",
    seed=42
)

validation_dataset = image_dataset_from_directory(
    directory,
    labels="inferred",
    label_mode="binary",
    class_names=['df', 'real'],
    color_mode="rgb",
    batch_size=BATCH_SIZE,
    image_size=(SIZE, SIZE),
    shuffle=True,
    validation_split=0.1,
    subset="validation",
    seed=42
)
# Out:
# Found 12353 files belonging to 2 classes.
# Using 11118 files for training.
# Found 12353 files belonging to 2 classes.
# Using 1235 files for validation.

# %%
steps_per_epoch=len(training_dataset)
print(steps_per_epoch)
# Out:
# 174

# %% [markdown]
# # Model

# %% [markdown]
# ## LR Decay

# %%
# This function keeps the initial learning rate for the first ten epochs  
# and decreases it exponentially after that.  
def scheduler(epoch):
    lr = 1e-3
    if epoch < 20:
        lr = 0.001 
    elif epoch >= 20 and epoch < 30:
        lr = 0.001
    elif epoch >= 30 and epoch < 40:
        lr = 0.0001
    elif epoch >= 40:
        lr = 0.00001
    print("{0:.8f}".format(lr))
    return lr

# %%
def InceptionLayer(f1, f2, f3, f4):
    def func(x):
        x1 = Conv2D(f1, (1, 1), padding='same', activation='relu')(x)     
        x2 = Conv2D(f2, (3, 3), padding='same', activation='relu')(x)       
        x3 = Conv2D(f3, (5, 5), padding='same', activation='relu')(x)       
        x4 = Conv2D(f4, (7, 7), padding='same', activation='relu')(x)
        y = Concatenate(axis = -1)([x1, x2, x3, x4])        
        return y
    return func
    
def CustomInception(input_shape):
    x = Input(shape = input_shape)
    
    x1 = InceptionLayer(1, 4, 4, 2)(x)
    x1 = BatchNormalization()(x1)
    x1 = MaxPooling2D(pool_size=(2, 2), padding='same')(x1)
    
    x2 = InceptionLayer(2, 4, 4, 2)(x1)
    x2 = InceptionLayer(2, 4, 4, 2)(x2)
    x2 = BatchNormalization()(x2)
    x2 = MaxPooling2D(pool_size=(2, 2), padding='same')(x2)        
    
    x3 = InceptionLayer(4, 8, 8, 4)(x2)
    x3 = InceptionLayer(4, 8, 8, 4)(x3)
    x3 = InceptionLayer(4, 8, 8, 4)(x3)
    x3 = BatchNormalization()(x3)
    x3 = MaxPooling2D(pool_size=(2, 2), padding='same')(x3)  

    x4 = Conv2D(16, (5, 5), padding='same', activation = 'relu')(x3)
    x4 = Conv2D(16, (5, 5), padding='same', activation = 'relu')(x4)
    x4 = BatchNormalization()(x4)
    x4 = MaxPooling2D(pool_size=(4, 4), padding='same')(x4)  

    x5 = Conv2D(32, (3, 3), padding='same', activation = 'relu')(x4)
    x5 = Conv2D(32, (3, 3), padding='same', activation = 'relu')(x5)
    x5 = Conv2D(32, (3, 3), padding='same', activation = 'relu')(x5)
    x5 = BatchNormalization()(x5)
    x5 = MaxPooling2D(pool_size=(4, 4), padding='same')(x5) 

    x6 = Conv2D(64, (3, 3), padding='same', activation = 'relu')(x5)
    x6 = Conv2D(64, (3, 3), padding='same', activation = 'relu')(x6)
    x6 = Conv2D(64, (3, 3), padding='same', activation = 'relu')(x6)
    x6 = Conv2D(64, (3, 3), padding='same', activation = 'relu')(x6)
    x6 = BatchNormalization()(x6)
    x6 = MaxPooling2D(pool_size=(4, 4), padding='same')(x6) 
    
    y = Flatten()(x6)
    y = Dropout(0.5)(y)
    y = Dense(16)(y)
    y = LeakyReLU(alpha=0.1)(y)
    y = Dropout(0.5)(y)
    y = Dense(1, activation = 'sigmoid')(y)

    return KerasModel(inputs = x, outputs = y), 'CustomInception'

# %% [markdown]
# ## Compile Model

# %%
from keras.models import Model as KerasModel
from keras.models import Sequential
from keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Dropout, Reshape, Concatenate, LeakyReLU, Embedding, LSTM
from keras.optimizers import Adam
'''
# %run -i 'classifiers.py'
'''
model, modelName = CustomInception(input_shape)
optimizer = Adam(lr = learning_rate)
model.compile(optimizer = optimizer, loss = 'mean_squared_error', metrics = ['accuracy'])
# model.summary()
print(modelName)
# Out:
# CustomInception

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Training

# %% [markdown]
# ## Fit Model

# %%
from tensorflow import keras
import keras.backend as K

callback = keras.callbacks.LearningRateScheduler(scheduler)

history = model.fit(training_dataset,
                    epochs=EPOCHS,
                    validation_data=validation_dataset,
                    verbose = 1,
                    steps_per_epoch=steps_per_epoch,
                    callbacks=[callback],
                    workers=4)
round(model.optimizer.lr.numpy(), 5)
# Out:
# Epoch 1/50
# 0.00100000
# 174/174 [==============================] - 21s 97ms/step - loss: 0.2061 - accuracy: 0.6609 - val_loss: 0.2044 - val_accuracy: 0.6551
# Epoch 2/50
# 0.00100000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0894 - accuracy: 0.8816 - val_loss: 0.0981 - val_accuracy: 0.8632
# Epoch 3/50
# 0.00100000
# 174/174 [==============================] - 17s 93ms/step - loss: 0.0642 - accuracy: 0.9159 - val_loss: 0.0987 - val_accuracy: 0.8696
# Epoch 4/50
# 0.00100000
# 174/174 [==============================] - 17s 93ms/step - loss: 0.0581 - accuracy: 0.9285 - val_loss: 0.0591 - val_accuracy: 0.9231
# Epoch 5/50
# 0.00100000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0389 - accuracy: 0.9494 - val_loss: 0.0486 - val_accuracy: 0.9336
# Epoch 6/50
# 0.00100000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0325 - accuracy: 0.9601 - val_loss: 0.0345 - val_accuracy: 0.9474
# Epoch 7/50
# 0.00100000
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0296 - accuracy: 0.9628 - val_loss: 0.0377 - val_accuracy: 0.9457
# Epoch 8/50
# 0.00100000
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0270 - accuracy: 0.9659 - val_loss: 0.0983 - val_accuracy: 0.8672
# Epoch 9/50
# 0.00100000
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0213 - accuracy: 0.9721 - val_loss: 0.0734 - val_accuracy: 0.9028
# Epoch 10/50
# 0.00100000
# 174/174 [==============================] - 16s 90ms/step - loss: 0.0283 - accuracy: 0.9664 - val_loss: 0.0215 - val_accuracy: 0.9709
# Epoch 11/50
# 0.00100000
# 174/174 [==============================] - 16s 90ms/step - loss: 0.0191 - accuracy: 0.9787 - val_loss: 0.2657 - val_accuracy: 0.6769
# Epoch 12/50
# 0.00100000
# 174/174 [==============================] - 16s 90ms/step - loss: 0.0289 - accuracy: 0.9632 - val_loss: 0.0527 - val_accuracy: 0.9312
# Epoch 13/50
# 0.00100000
# 174/174 [==============================] - 17s 93ms/step - loss: 0.0204 - accuracy: 0.9744 - val_loss: 0.0856 - val_accuracy: 0.8915
# Epoch 14/50
# 0.00100000
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0152 - accuracy: 0.9809 - val_loss: 0.0225 - val_accuracy: 0.9717
# Epoch 15/50
# 0.00100000
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0105 - accuracy: 0.9877 - val_loss: 0.0523 - val_accuracy: 0.9344
# Epoch 16/50
# 0.00100000
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0250 - accuracy: 0.9699 - val_loss: 0.0654 - val_accuracy: 0.9247
# Epoch 17/50
# 0.00100000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0136 - accuracy: 0.9831 - val_loss: 0.0422 - val_accuracy: 0.9409
# Epoch 18/50
# 0.00100000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0130 - accuracy: 0.9844 - val_loss: 0.0651 - val_accuracy: 0.9117
# Epoch 19/50
# 0.00100000
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0106 - accuracy: 0.9865 - val_loss: 0.0423 - val_accuracy: 0.9530
# Epoch 20/50
# 0.00100000
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0163 - accuracy: 0.9806 - val_loss: 0.0370 - val_accuracy: 0.9547
# Epoch 21/50
# 0.00100000
# 174/174 [==============================] - 16s 90ms/step - loss: 0.0145 - accuracy: 0.9831 - val_loss: 0.0947 - val_accuracy: 0.8802
# Epoch 22/50
# 0.00100000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0167 - accuracy: 0.9800 - val_loss: 0.0290 - val_accuracy: 0.9652
# Epoch 23/50
# 0.00100000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0100 - accuracy: 0.9873 - val_loss: 0.0920 - val_accuracy: 0.8955
# Epoch 24/50
# 0.00100000
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0130 - accuracy: 0.9844 - val_loss: 0.3386 - val_accuracy: 0.6551
# Epoch 25/50
# 0.00100000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0144 - accuracy: 0.9833 - val_loss: 0.0462 - val_accuracy: 0.9425
# Epoch 26/50
# 0.00100000
# 174/174 [==============================] - 17s 93ms/step - loss: 0.0072 - accuracy: 0.9910 - val_loss: 0.1059 - val_accuracy: 0.8632
# Epoch 27/50
# 0.00100000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0159 - accuracy: 0.9808 - val_loss: 0.0266 - val_accuracy: 0.9668
# Epoch 28/50
# 0.00100000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0093 - accuracy: 0.9877 - val_loss: 0.0675 - val_accuracy: 0.9101
# Epoch 29/50
# 0.00100000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0089 - accuracy: 0.9893 - val_loss: 0.0426 - val_accuracy: 0.9530
# Epoch 30/50
# 0.00100000
# 174/174 [==============================] - 16s 90ms/step - loss: 0.0160 - accuracy: 0.9804 - val_loss: 0.0225 - val_accuracy: 0.9700
# Epoch 31/50
# 0.00010000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0060 - accuracy: 0.9917 - val_loss: 0.0154 - val_accuracy: 0.9814
# Epoch 32/50
# 0.00010000
# 174/174 [==============================] - 17s 95ms/step - loss: 0.0036 - accuracy: 0.9957 - val_loss: 0.0141 - val_accuracy: 0.9814
# Epoch 33/50
# 0.00010000
# 174/174 [==============================] - 17s 93ms/step - loss: 0.0029 - accuracy: 0.9972 - val_loss: 0.0132 - val_accuracy: 0.9838
# Epoch 34/50
# 0.00010000
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0017 - accuracy: 0.9983 - val_loss: 0.0124 - val_accuracy: 0.9854
# Epoch 35/50
# 0.00010000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0020 - accuracy: 0.9980 - val_loss: 0.0121 - val_accuracy: 0.9862
# Epoch 36/50
# 0.00010000
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0020 - accuracy: 0.9981 - val_loss: 0.0116 - val_accuracy: 0.9846
# Epoch 37/50
# 0.00010000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0019 - accuracy: 0.9982 - val_loss: 0.0107 - val_accuracy: 0.9854
# Epoch 38/50
# 0.00010000
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0019 - accuracy: 0.9982 - val_loss: 0.0109 - val_accuracy: 0.9862
# Epoch 39/50
# 0.00010000
# 174/174 [==============================] - 17s 95ms/step - loss: 0.0017 - accuracy: 0.9983 - val_loss: 0.0114 - val_accuracy: 0.9870
# Epoch 40/50
# 0.00010000
# 174/174 [==============================] - 17s 93ms/step - loss: 0.0013 - accuracy: 0.9987 - val_loss: 0.0107 - val_accuracy: 0.9862
# Epoch 41/50
# 0.00001000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0016 - accuracy: 0.9985 - val_loss: 0.0111 - val_accuracy: 0.9870
# Epoch 42/50
# 0.00001000
# 174/174 [==============================] - 17s 94ms/step - loss: 0.0013 - accuracy: 0.9990 - val_loss: 0.0110 - val_accuracy: 0.9870
# Epoch 43/50
# 0.00001000
# 174/174 [==============================] - 17s 93ms/step - loss: 0.0011 - accuracy: 0.9989 - val_loss: 0.0110 - val_accuracy: 0.9870
# Epoch 44/50
# 0.00001000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0012 - accuracy: 0.9987 - val_loss: 0.0110 - val_accuracy: 0.9870
# Epoch 45/50
# 0.00001000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0011 - accuracy: 0.9990 - val_loss: 0.0110 - val_accuracy: 0.9870
# Epoch 46/50
# 0.00001000
# 174/174 [==============================] - 16s 92ms/step - loss: 0.0012 - accuracy: 0.9988 - val_loss: 0.0110 - val_accuracy: 0.9870
# Epoch 47/50
# 0.00001000
# 174/174 [==============================] - 16s 91ms/step - loss: 0.0011 - accuracy: 0.9991 - val_loss: 0.0110 - val_accuracy: 0.9862
# Epoch 48/50
# 0.00001000
# 174/174 [==============================] - 17s 93ms/step - loss: 0.0012 - accuracy: 0.9991 - val_loss: 0.0109 - val_accuracy: 0.9870
# Epoch 49/50
# 0.00001000
# 174/174 [==============================] - 16s 92ms/step - loss: 9.9849e-04 - accuracy: 0.9990 - val_loss: 0.0108 - val_accuracy: 0.9870
# Epoch 50/50
# 0.00001000
# 174/174 [==============================] - 17s 93ms/step - loss: 0.0013 - accuracy: 0.9987 - val_loss: 0.0110 - val_accuracy: 0.9870
# 1e-05

# %% [markdown]
# ## Training and Validation Graphs

# %%
import matplotlib.pyplot as plt

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 4))
t = f.suptitle('Training and Validation Performance for ' + modelName, fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,EPOCHS+1))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, EPOCHS+1, 1))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch #')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, EPOCHS+1, 1))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch #')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %% [markdown]
# # Prediction

# %% [markdown]
# ## Store into tf.data.Dataset

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

directory = os.path.join('deepfake_database', 'validation')
image_format = '.jpg'

test_dataset = image_dataset_from_directory(
    directory,
    labels="inferred",
    label_mode="binary",
    class_names=['df', 'real'],
    color_mode="rgb",
    batch_size=BATCH_SIZE,
    image_size=(SIZE, SIZE),
    shuffle=False,
)
# Out:
# Found 7104 files belonging to 2 classes.

# %% [markdown]
# ## Make Prediction

# %%
Y_pred = (model.predict(test_dataset, verbose=1) > 0.5).astype("int32")
# Out:
# 111/111 [==============================] - 7s 59ms/step

# %% [markdown]
# ### Read Original Labels

# %%
Y_test = []
for img_array, label in (test_dataset.as_numpy_iterator()):
    Y_test.append(label)

# %% [markdown]
# ### Flatten Original and Prediction label arrays

# %%
original_labels = []
original_labels = list(np.concatenate(Y_test).flat)
original_labels = np.array(original_labels)

predicted_labels = []
predicted_labels = list(np.concatenate(Y_pred).flat)
predicted_labels = np.array(predicted_labels)

# %% [markdown]
# ## Classification Report

# %%
from sklearn.metrics import classification_report
classificationReport = classification_report(original_labels, predicted_labels, target_names=test_dataset.class_names)
print(classificationReport)
# Out:
#               precision    recall  f1-score   support
#
#           df       0.80      0.93      0.86      2845
#         real       0.94      0.85      0.89      4259
#
#     accuracy                           0.88      7104
#    macro avg       0.87      0.89      0.88      7104
# weighted avg       0.89      0.88      0.88      7104

# %% [markdown]
# ## Confusion Matrix

# %%
#Output confusion matrix
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

def print_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    print('True positive = ', cm[0][0])
    print('False positive = ', cm[0][1])
    print('False negative = ', cm[1][0])
    print('True negative = ', cm[1][1])
    print('\n')
    df_cm = pd.DataFrame(cm, range(2), range(2))
    sn.set(font_scale=1.4) # for label size
    sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, cmap="YlGnBu") # font size
    plt.ylabel('Actual label', size = 20)
    plt.xlabel('Predicted label', size = 20)
    plt.xticks(np.arange(2), test_dataset.class_names, size = 16)
    plt.yticks(np.arange(2), test_dataset.class_names, size = 16)
    plt.ylim([2, 0])
    plt.show()
    return cm
    
confusionMatrix = print_confusion_matrix(original_labels, predicted_labels)
# Out:
# True positive =  2632
# False positive =  213
# False negative =  646
# True negative =  3613

# %% [markdown]
# # Write to File

# %%
import os

tp = str('True positive = '+ str(confusionMatrix[0][0]) + '\n')
fp = str('False positive = '+ str(confusionMatrix[0][1]) + '\n')
fn = str('False negative = '+ str(confusionMatrix[1][0]) + '\n')
tn = str('True negative = '+ str(confusionMatrix[1][1]) + '\n')

data = (
    'Model Name: ' + str(modelName) + '\n' +
    'Batch Size: ' + str(BATCH_SIZE) + '\n' +
    'Image Size: ' + str(SIZE) + '\n' +
    'Epochs: ' + str(EPOCHS) + '\n' +
    '===================================================== \n\n' +
    str(classificationReport) + '\n' + str(tp + fp + fn + tn)
)

from datetime import datetime 
import pytz 
  
# get the standard UTC time  
UTC = pytz.utc 
  
# it will get the time zone  
# of the specified location 
IST = pytz.timezone('Asia/Kolkata') 
  
datetime_ist = datetime.now(IST) 
filename = ('Report ' + datetime_ist.strftime('%Y-%m-%d %H%M') + ' ' + modelName + '.txt')

myFile = open(filename, 'w')
myFile.write(data)
myFile.close()

model.save(modelName + ' ' + datetime_ist.strftime('%Y-%m-%d %H%M') + '.h5')
